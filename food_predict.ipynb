# %% [markdown]
# <a href="https://colab.research.google.com/github/ellieytc/CaseStudy.DeepLearning/blob/master/food_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Aug 20 12:18:10 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    60W / 149W |   8427MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import zipfile
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/My Drive/Tibame/dataset/food_image.zip'

zip_ref = zipfile.ZipFile(path, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

os.chdir('/tmp')
os.listdir('/tmp')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['model-food-final.h5',
#  'tmprg7cnhqk.py',
#  '__pycache__',
#  'tmpaqy_71ek.py',
#  'tmpkt4kjxar',
#  'food_train_model.pkl',
#  'drivefs_ipc.0_shell',
#  'tmpk_mpidv7.py',
#  'food_train',
#  'food_test',
#  'drivefs_ipc.0']

# %%
# import library
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.models import load_model
from tensorflow.python.keras.preprocessing import image
import numpy as np

# %%
# load model
model = load_model('model-food-final.h5')
# pd.read_pickle('./food_train_model.pkl')

# %%
# load images
test_dataset_path = '/tmp/food_test/'
test_filenames = os.listdir(test_dataset_path)
test_df = pd.DataFrame({'filename': test_filenames})
nb_samples = test_df.shape[0]
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(test_df, 
    test_dataset_path, 
    x_col='filename',
    y_col=None,
    class_mode=None,
    batch_size=7,
    target_size=(200, 200),
    shuffle=False)
# Out:
# Found 1422 validated image filenames.

# %%
# predict the category
# labels = ['apple','cabbage','carrot','chicken','cucumber','egg','mushroom','potato','radish','tomato']
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
test_df['category'] = pd.DataFrame(np.argmax(predict, axis=1))

# %%
for i in test_df['category']:
  if i == 0:
    print('apple')
  elif i == 1:
    print('cabbage')
  elif i == 2:
    print('carrot')
  elif i == 3:
    print('chicken')
  elif i == 4:
    print('cucumber')
  elif i == 5:
    print('egg')
  elif i == 6:
    print('mushroom')
  elif i == 7:
    print('potato')
  elif i == 8:
    print('radish')
  elif i == 9:
    print('tomato')
  else: 
    print('圖片無法辨識，請輸入文字...')
# Out:
# cabbage
# tomato
# egg
# cucumber
# apple
# radish
# cucumber
# apple
# egg
# carrot
# carrot
# apple
# cucumber
# apple
# radish
# tomato
# apple
# tomato
# cucumber
# potato
# cabbage
# mushroom
# apple
# chicken
# carrot
# apple
# carrot
# egg
# mushroom
# carrot
# apple
# tomato
# tomato
# cucumber
# egg
# egg
# mushroom
# egg
# apple
# egg
# tomato
# radish
# radish
# potato
# carrot
# apple
# cabbage
# cucumber
# apple
# cucumber
# mushroom
# apple
# apple
# cucumber
# egg
# tomato
# cucumber
# apple
# egg
# cucumber
# apple
# tomato
# radish
# potato
# egg
# tomato
# cucumber
# apple
# cucumber
# radish
# potato
# cabbage
# cucumber
# tomato
# carrot
# apple
# radish
# apple
# tomato
# cucumber
# potato
# egg
# egg
# tomato
# egg
# radish
# apple
# tomato
# egg
# egg
# tomato
# potato
# carrot
# cucumber
# cabbage
# apple
# cucumber
# apple
# cabbage
# egg
# tomato
# potato
# cucumber
# cucumber
# cucumber
# egg
# egg
# apple
# apple
# carrot
# carrot
# egg
# apple
# cabbage
# tomato
# radish
# cucumber
# egg
# tomato
# tomato
# carrot
# apple
# cucumber
# cabbage
# tomato
# egg
# radish
# tomato
# potato
# cabbage
# apple
# potato
# potato
# potato
# potato
# egg
# cabbage
# mushroom
# tomato
# tomato
# tomato
# mushroom
# egg
# egg
# tomato
# cucumber
# tomato
# radish
# mushroom
# apple
# cucumber
# apple
# cabbage
# apple
# tomato
# tomato
# egg
# apple
# egg
# carrot
# cabbage
# tomato
# apple
# egg
# cabbage
# potato
# egg
# carrot
# apple
# cucumber
# egg
# chicken
# radish
# carrot
# carrot
# apple
# apple
# tomato
# egg
# potato
# egg
# cabbage
# egg
# tomato
# apple
# chicken
# tomato
# cucumber
# cabbage
# egg
# apple
# cucumber
# egg
# apple
# cabbage
# apple
# potato
# tomato
# radish
# cucumber
# cabbage
# egg
# cucumber
# cucumber
# potato
# cabbage
# cucumber
# carrot
# apple
# apple
# carrot
# cabbage
# tomato
# egg
# cabbage
# potato
# tomato
# cucumber
# potato
# chicken
# egg
# tomato
# apple
# egg
# cucumber
# tomato
# apple
# egg
# cucumber
# mushroom
# tomato
# carrot
# egg
# carrot
# cabbage
# cucumber
# egg
# radish
# radish
# tomato
# carrot
# tomato
# cucumber
# cabbage
# apple
# egg
# tomato
# radish
# egg
# potato
# tomato
# apple
# apple
# carrot
# carrot
# radish
# potato
# tomato
# mushroom
# cabbage
# potato
# potato
# cucumber
# potato
# cabbage
# potato
# apple
# apple
# apple
# carrot
# cabbage
# tomato
# radish
# apple
# tomato
# cabbage
# apple
# mushroom
# apple
# tomato
# potato
# apple
# cucumber
# carrot
# cucumber
# cucumber
# cabbage
# potato
# carrot
# radish
# egg
# potato
# apple
# cucumber
# cucumber
# apple
# cucumber
# tomato
# egg
# radish
# apple
# carrot
# egg
# tomato
# carrot
# apple
# radish
# radish
# tomato
# apple
# cucumber
# cabbage
# cucumber
# egg
# tomato
# egg
# tomato
# egg
# apple
# apple
# egg
# apple
# potato
# tomato
# radish
# radish
# mushroom
# apple
# egg
# cucumber
# cucumber
# carrot
# apple
# potato
# egg
# carrot
# carrot
# mushroom
# carrot
# tomato
# radish
# apple
# radish
# tomato
# apple
# egg
# apple
# cucumber
# radish
# egg
# apple
# mushroom
# apple
# cabbage
# cabbage
# egg
# apple
# egg
# mushroom
# potato
# carrot
# apple
# carrot
# egg
# mushroom
# cucumber
# mushroom
# apple
# tomato
# cucumber
# egg
# egg
# egg
# cabbage
# cucumber
# radish
# cucumber
# apple
# cabbage
# radish
# cucumber
# tomato
# apple
# apple
# potato
# potato
# cucumber
# mushroom
# cucumber
# apple
# potato
# tomato
# cabbage
# cabbage
# carrot
# egg
# tomato
# mushroom
# cucumber
# egg
# radish
# cucumber
# radish
# apple
# egg
# cabbage
# tomato
# radish
# egg
# cabbage
# mushroom
# egg
# chicken
# cucumber
# potato
# potato
# cucumber
# potato
# cabbage
# cucumber
# cabbage
# cucumber
# cucumber
# egg
# apple
# apple
# carrot
# apple
# egg
# cabbage
# apple
# cucumber
# radish
# cucumber
# radish
# carrot
# egg
# carrot
# egg
# egg
# radish
# apple
# cucumber
# carrot
# potato
# carrot
# apple
# cucumber
# cucumber
# apple
# radish
# tomato
# apple
# carrot
# apple
# apple
# tomato
# egg
# egg
# carrot
# cucumber
# mushroom
# cucumber
# carrot
# mushroom
# carrot
# cucumber
# radish
# cucumber
# tomato
# tomato
# radish
# apple
# egg
# cabbage
# cucumber
# potato
# cucumber
# mushroom
# potato
# tomato
# cucumber
# tomato
# potato
# potato
# radish
# apple
# egg
# apple
# tomato
# chicken
# mushroom
# egg
# apple
# tomato
# egg
# egg
# egg
# cucumber
# apple
# apple
# radish
# tomato
# egg
# carrot
# tomato
# egg
# tomato
# potato
# apple
# egg
# cucumber
# egg
# apple
# mushroom
# cucumber
# radish
# apple
# radish
# potato
# egg
# egg
# tomato
# mushroom
# carrot
# apple
# carrot
# apple
# carrot
# carrot
# cucumber
# tomato
# potato
# cucumber
# egg
# apple
# potato
# cucumber
# apple
# cabbage
# apple
# radish
# egg
# mushroom
# egg
# tomato
# egg
# egg
# tomato
# mushroom
# cucumber
# apple
# apple
# egg
# apple
# radish
# egg
# tomato
# potato
# tomato
# egg
# egg
# apple
# apple
# carrot
# egg
# cucumber
# egg
# cucumber
# apple
# radish
# cucumber
# egg
# radish
# egg
# apple
# tomato
# potato
# cucumber
# apple
# radish
# apple
# apple
# egg
# egg
# radish
# chicken
# radish
# cucumber
# tomato
# apple
# cucumber
# carrot
# tomato
# apple
# tomato
# cucumber
# tomato
# tomato
# potato
# carrot
# egg
# cabbage
# carrot
# apple
# cucumber
# tomato
# egg
# apple
# apple
# radish
# egg
# cabbage
# tomato
# cabbage
# apple
# cabbage
# egg
# potato
# tomato
# potato
# mushroom
# apple
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
# 無法辨識，請輸入文字...
